# %%
from PIL import Image
import numpy as np

img1=Image.open('Images/land.jpg')
arr=np.array(img1)
arr
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x797 at 0x1CAFF072B20>

# %%
import cv2
im=cv2.imread('Images/land.jpg')
im
# Out:
# array([[[23, 11, 11],
#         [24, 12, 12],
#         [26, 14, 14],
#         ...,
#         [30, 12, 13],
#         [30, 12, 13],
#         [30, 12, 13]],
#
#        [[23, 11, 11],
#         [24, 12, 12],
#         [26, 14, 14],
#         ...,
#         [30, 12, 13],
#         [30, 12, 13],
#         [30, 12, 13]],
#
#        [[23, 10, 12],
#         [24, 11, 13],
#         [25, 12, 14],
#         ...,
#         [30, 12, 13],
#         [30, 12, 13],
#         [30, 12, 13]],
#
#        ...,
#
#        [[ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         ...,
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4]],
#
#        [[ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         ...,
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4]],
#
#        [[ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         ...,
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4]]], dtype=uint8)
